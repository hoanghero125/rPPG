# %%
import os
import sys
import json
import glob
import math
import shutil
import numpy as np
import pandas as pd
import cv2
from scipy import signal
from scipy.signal import periodogram
from tqdm import tqdm
import torch
import torch.multiprocessing
torch.multiprocessing.set_sharing_strategy('file_system')
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

REPO_ROOT = "/home/naver/disk2/HoangDPB/rPPG-Toolbox"
if REPO_ROOT not in sys.path:
    sys.path.insert(0, REPO_ROOT)

from neural_methods.model.PhysMamba import PhysMamba
# Out:
# /home/naver/miniconda3/envs/rppg-toolbox/lib/python3.8/site-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)

# %%
# ----- paths -----
RAW_DATA_PATH       = os.path.join(REPO_ROOT, "raw_data/PPG_Dataset")
PREPROCESSED_PATH   = os.path.join(REPO_ROOT, "preprocessed_data/groupE")
OUTPUT_DIR          = os.path.join(REPO_ROOT, "results/groupE/PPG_Dataset")

# ----- video / signal params -----
VIDEO_FPS   = 30       # camera frame rate
PPG_FS      = 25       # PPG sensor sampling rate (Hz)

# ----- PhysMamba preprocessing params -----
CHUNK_LENGTH = 128     # frames per clip
IMG_H, IMG_W = 128, 128
LABEL_TYPE   = "DiffNormalized"  # cumsum in post-processing
DATA_FORMAT  = "NCDHW"

# ----- device -----
DEVICE = "cuda:0" if torch.cuda.is_available() else "cpu"
print("Device:", DEVICE)

os.makedirs(PREPROCESSED_PATH, exist_ok=True)
os.makedirs(OUTPUT_DIR, exist_ok=True)
print("PREPROCESSED_PATH:", PREPROCESSED_PATH)
print("OUTPUT_DIR:", OUTPUT_DIR)
# Out:
# Device: cuda:0
# PREPROCESSED_PATH: /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE
# OUTPUT_DIR: /home/naver/disk2/HoangDPB/rPPG-Toolbox/results/groupE/PPG_Dataset

# %%
# Model toggle
MODELS = [
    ("PURE_PhysMamba",             "PhysMamba", "final_model_release/PURE_PhysMamba_DiffNormalized.pth"),
    ("UBFC-rPPG_PhysMamba",      "PhysMamba", "final_model_release/UBFC-rPPG_PhysMamba_DiffNormalized.pth"),
]

# Select which model to use (index into MODELS list)
SELECTED_MODEL_IDX = 0
MODEL_LABEL, MODEL_NAME, MODEL_REL_PATH = MODELS[SELECTED_MODEL_IDX]
MODEL_PATH = os.path.join(REPO_ROOT, MODEL_REL_PATH)
print(f"Selected model: {MODEL_LABEL}")
print(f"Model path: {MODEL_PATH}")
# Out:
# Selected model: PURE_PhysMamba
# Model path: /home/naver/disk2/HoangDPB/rPPG-Toolbox/final_model_release/PURE_PhysMamba_DiffNormalized.pth

# %%
# Read video frames

def read_video_frames(video_path):
    """Read all frames from an MP4 file.

    Returns:
        frames (np.ndarray): shape (T, H, W, 3), dtype uint8, RGB order.
    """
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        raise IOError(f"Cannot open video: {video_path}")

    frames = []
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        frames.append(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    cap.release()

    if not frames:
        raise ValueError(f"Empty video: {video_path}")
    return np.stack(frames, axis=0)

# %%
# Read and time-align PPG signal

def read_ppg_synced(session_path, num_frames, fps=30):
    """Read PPG green channel from ppg.csv and resample to video frame times.

    The PPG sensor timestamps and video start timestamp are both in ms
    Unix epoch stored in metadata.json (sync_markers.video_start).
    Resampling is done by linear interpolation onto frame-spaced timestamps.

    Returns:
        ppg (np.ndarray): shape (num_frames,), dtype float32, raw green values.
    """
    meta_path = os.path.join(session_path, "metadata.json")
    with open(meta_path, "r") as f:
        meta = json.load(f)
    video_start_ms = meta["sync_markers"].get("video_start")
    if video_start_ms is None:
        video_start_ms = meta.get("start_timestamp")
    if video_start_ms is None:
        raise ValueError(f"No video_start or start_timestamp found in {meta_path}")
    video_start_ms = float(video_start_ms)

    ppg_df = pd.read_csv(os.path.join(session_path, "ppg.csv"))
    ppg_ts    = ppg_df["timestamp"].values.astype(np.float64)
    ppg_green = ppg_df["green"].values.astype(np.float64)

    # convert ppg timestamps to seconds relative to video start
    ppg_t = (ppg_ts - video_start_ms) / 1000.0

    # frame timestamps in seconds
    frame_t = np.arange(num_frames, dtype=np.float64) / fps

    # clip frame times to valid ppg range to avoid extrapolation
    frame_t_clipped = np.clip(frame_t, ppg_t[0], ppg_t[-1])

    ppg_resampled = np.interp(frame_t_clipped, ppg_t, ppg_green)
    return ppg_resampled.astype(np.float32)

# %%
# Normalization functions (DiffNormalized for groupE)

def diff_normalize_data(data):
    """DiffNormalized: (frame[t+1]-frame[t]) / (frame[t+1]+frame[t]+1e-7), then / std."""
    data = data.astype(np.float32)
    n, h, w, c = data.shape
    out = np.zeros_like(data)
    out[:n - 1] = (data[1:] - data[:-1]) / (data[1:] + data[:-1] + 1e-7)
    std = np.std(out)
    if std > 0:
        out /= std
    return out


def diff_normalize_label(label):
    """DiffNormalized label: finite difference normalised by std, zero-padded."""
    diff = np.diff(label.astype(np.float64), axis=0)
    s = np.std(diff)
    if s > 0:
        diff = diff / s
    return np.append(diff, [0.0]).astype(np.float32)

# %%
# Face crop + resize

def crop_face_resize(frames, out_h, out_w, large_box_coef=1.5):
    """Detect face on frame 0, expand bbox by coef, resize all frames."""
    xml_path = cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
    detector  = cv2.CascadeClassifier(xml_path)

    frame0 = frames[0]
    if frame0.dtype != np.uint8:
        frame0 = np.clip(frame0, 0, 255).astype(np.uint8)
    gray = cv2.cvtColor(frame0, cv2.COLOR_RGB2GRAY)

    faces = detector.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=5)
    H, W = frames.shape[1], frames.shape[2]

    if len(faces) > 0:
        x, y, fw, fh = max(faces, key=lambda f: f[2])  # largest face
        x  = max(0, int(x  - (large_box_coef - 1.0) / 2.0 * fw))
        y  = max(0, int(y  - (large_box_coef - 1.0) / 2.0 * fh))
        fw = min(int(fw * large_box_coef), W - x)
        fh = min(int(fh * large_box_coef), H - y)
    else:
        x, y, fw, fh = 0, 0, W, H  # fallback: full frame

    C = frames.shape[3]
    resized = np.zeros((len(frames), out_h, out_w, C), dtype=np.float32)
    for i, frame in enumerate(frames):
        crop = frame[y : y + fh, x : x + fw]
        if crop.size == 0:
            crop = frame
        resized[i] = cv2.resize(crop.astype(np.float32), (out_w, out_h),
                                interpolation=cv2.INTER_AREA)
    return resized

# %%
# Discover subjects + read device-measured HR from hr.csv

def read_gt_hr(session_path):
    """Return average HR from hr.csv (hrStatus==1, hr>0).

    hr.csv has IBI columns whose values are arrays like [720, 695],
    which contain commas and break the standard CSV parser.
    Reading only the first 5 columns avoids the issue.
    """
    hr_path = os.path.join(session_path, "hr.csv")
    df = pd.read_csv(
        hr_path,
        usecols=[0, 1, 2, 3, 4],
        names=["id", "dataReceived", "timestamp", "hr", "hrStatus"],
        header=0,
    )
    valid = df[(df["hrStatus"] == 1) & (df["hr"] > 0)]["hr"]
    if len(valid) == 0:
        return float("nan")
    return float(valid.mean())


# Discover subject folders directly
all_dirs = sorted([
    d for d in glob.glob(os.path.join(RAW_DATA_PATH, "*"))
    if os.path.isdir(d) and os.path.basename(d) != "videos"
])
print(f"Found {len(all_dirs)} subject folders\n")

subjects = []

for subj_dir in all_dirs:
    subj_id  = os.path.basename(subj_dir)
    subj_key = subj_id.replace("_", "")

    session_dirs = glob.glob(os.path.join(RAW_DATA_PATH, subj_id, "*"))
    if not session_dirs:
        print(f"No session folder for {subj_id}, skipping.")
        continue
    session_path = session_dirs[0]

    session_name  = os.path.basename(session_path)
    video_pattern = os.path.join(RAW_DATA_PATH, "videos",
                                  f"{subj_id}_{session_name}.mp4")
    video_files = glob.glob(video_pattern)
    if not video_files:
        print(f"No video found for {subj_id}, skipping.")
        continue
    video_path = video_files[0]

    gt_hr = read_gt_hr(session_path)

    subjects.append({
        "subj_id":      subj_id,
        "subj_key":     subj_key,
        "video_path":   video_path,
        "session_path": session_path,
        "gt_hr":        gt_hr,
    })
    print(f"  {subj_id}  HR_device={gt_hr:.4f} bpm  video={os.path.basename(video_path)}")

print(f"\nTotal subjects: {len(subjects)}")
# Out:
# Found 60 subject folders
#
#   S_000  HR_device=83.5375 bpm  video=S_000_baseline_1768470386897.mp4
#   S_001  HR_device=80.3974 bpm  video=S_001_baseline_1768465415430.mp4
#   S_002  HR_device=122.4792 bpm  video=S_002_baseline_1768559029065.mp4
#   S_003  HR_device=114.9216 bpm  video=S_003_baseline_1768561970957.mp4
#   S_004  HR_device=79.1250 bpm  video=S_004_baseline_1768560982129.mp4
#   S_005  HR_device=92.7875 bpm  video=S_005_baseline_1768558641873.mp4
#   S_006  HR_device=106.7284 bpm  video=S_006_baseline_1768557426231.mp4
#   S_007  HR_device=103.5309 bpm  video=S_007_baseline_1768560100207.mp4
#   S_008  HR_device=90.2963 bpm  video=S_008_baseline_1768559192265.mp4
#   S_009  HR_device=81.0886 bpm  video=S_009_baseline_1768032143238.mp4
#   S_010  HR_device=98.0617 bpm  video=S_010_baseline_1768548590301.mp4
#   S_011  HR_device=72.5679 bpm  video=S_011_baseline_1768560819006.mp4
#   S_012  HR_device=81.4881 bpm  video=S_012_baseline_1768791488131.mp4
#   S_013  HR_device=90.2449 bpm  video=S_013_baseline_1768560627600.mp4
#   S_014  HR_device=83.3333 bpm  video=S_014_baseline_1768559417753.mp4
#   S_015  HR_device=79.2118 bpm  video=S_015_baseline_1768790780793.mp4
#   S_016  HR_device=95.4810 bpm  video=S_016_baseline_1768471077177.mp4
#   S_017  HR_device=90.5857 bpm  video=S_017_baseline_1768471356601.mp4
#   S_018  HR_device=86.0000 bpm  video=S_018_baseline_1768557829326.mp4
#   S_019  HR_device=96.5375 bpm  video=S_019_baseline_1768558071354.mp4
#   S_020  HR_device=80.9268 bpm  video=S_020_baseline_1768793107126.mp4
#   S_021  HR_device=118.4648 bpm  video=S_021_baseline_1768548398905.mp4
#   S_022  HR_device=87.1429 bpm  video=S_022_baseline_1768467220962.mp4
#   S_023  HR_device=77.5185 bpm  video=S_023_baseline_1768034216185.mp4
#   S_024  HR_device=77.1818 bpm  video=S_024_baseline_1768035128149.mp4
#   S_025  HR_device=61.4750 bpm  video=S_025_baseline_1768559860433.mp4
#   S_026  HR_device=70.5062 bpm  video=S_026_baseline_1768032698064.mp4
#   S_027  HR_device=102.0778 bpm  video=S_027_baseline_1768561461016.mp4
#   S_028  HR_device=73.8873 bpm  video=S_028_baseline_1768561639690.mp4
#   S_029  HR_device=97.8861 bpm  video=S_029_baseline_1768558828851.mp4
#   S_030  HR_device=79.4268 bpm  video=S_030_baseline_1768469999827.mp4
#   S_031  HR_device=91.3951 bpm  video=S_031_baseline_1768562241589.mp4
#   S_032  HR_device=86.8684 bpm  video=S_032_baseline_1768023899712.mp4
#   S_033  HR_device=85.6375 bpm  video=S_033_baseline_1768465796513.mp4
#   S_034  HR_device=94.2857 bpm  video=S_034_baseline_1768562642289.mp4
#   S_035  HR_device=109.9773 bpm  video=S_035_baseline_1768557024943.mp4
#   S_036  HR_device=81.4691 bpm  video=S_036_baseline_1768469370708.mp4
#   S_037  HR_device=71.8171 bpm  video=S_037_baseline_1768561791203.mp4
#   S_038  HR_device=66.0250 bpm  video=S_038_baseline_1768561157725.mp4
#   S_039  HR_device=102.0533 bpm  video=S_039_baseline_1768556605660.mp4
#   S_040  HR_device=90.4634 bpm  video=S_040_baseline_1768792509242.mp4
#   S_041  HR_device=117.7123 bpm  video=S_041_baseline_1768558424868.mp4
#   S_042  HR_device=62.9383 bpm  video=S_042_baseline_1768464260096.mp4
#   S_043  HR_device=57.7808 bpm  video=S_043_baseline_1768561306447.mp4
#   S_044  HR_device=75.1807 bpm  video=S_044_baseline_1768560412984.mp4
#   S_045  HR_device=75.6500 bpm  video=S_045_baseline_1768024581063.mp4
#   S_046  HR_device=62.8750 bpm  video=S_046_baseline_1768469543298.mp4
#   S_047  HR_device=70.9268 bpm  video=S_047_baseline_1768469715322.mp4
#   S_048  HR_device=101.6709 bpm  video=S_048_baseline_1768558268258.mp4
#   S_049  HR_device=63.8000 bpm  video=S_049_baseline_1768790445982.mp4
#   S_050  HR_device=87.7683 bpm  video=S_050_baseline_1768559635669.mp4
#   S_051  HR_device=80.1646 bpm  video=S_051_baseline_1768022543285.mp4
#   S_052  HR_device=71.1205 bpm  video=S_052_baseline_1768791873167.mp4
#   S_053  HR_device=69.1600 bpm  video=S_053_baseline_1768468421043.mp4
#   S_054  HR_device=64.5952 bpm  video=S_054_baseline_1768791154639.mp4
#   S_055  HR_device=73.0000 bpm  video=S_055_baseline_1768033753839.mp4
#   S_056  HR_device=97.2099 bpm  video=S_056_baseline_1768464659392.mp4
#   S_057  HR_device=68.4444 bpm  video=S_057_baseline_1768467567134.mp4
#   S_058  HR_device=79.9625 bpm  video=S_058_baseline_1768468115471.mp4
#   S_059  HR_device=78.7391 bpm  video=S_059_baseline_1768464873797.mp4
#
# Total subjects: 60

# %%
# Data preprocessing

# Clear any previous preprocessed data
if os.path.exists(PREPROCESSED_PATH):
    shutil.rmtree(PREPROCESSED_PATH)
os.makedirs(PREPROCESSED_PATH)
print(f"Cleared and recreated: {PREPROCESSED_PATH}\n")

all_input_files = []

for subj in subjects:
    subj_key     = subj["subj_key"]
    video_path   = subj["video_path"]
    session_path = subj["session_path"]

    print(f"=== Processing {subj_key} ===")

    frames = read_video_frames(video_path)
    T = frames.shape[0]
    print(f"  Video: {T} frames @ {VIDEO_FPS} fps")

    ppg_signal = read_ppg_synced(session_path, T, fps=VIDEO_FPS)
    print(f"  PPG green: min={ppg_signal.min():.0f}, max={ppg_signal.max():.0f}")

    # Crop face and resize to target resolution
    frames_cropped = crop_face_resize(frames, IMG_H, IMG_W)

    # DiffNormalized input data (3 channels)
    data_normalized = diff_normalize_data(frames_cropped)

    # DiffNormalized label
    label_normalized = diff_normalize_label(ppg_signal)

    # Chunk into clips
    clip_num = T // CHUNK_LENGTH
    data_clips  = np.array([data_normalized[i*CHUNK_LENGTH:(i+1)*CHUNK_LENGTH]  for i in range(clip_num)])
    label_clips = np.array([label_normalized[i*CHUNK_LENGTH:(i+1)*CHUNK_LENGTH] for i in range(clip_num)])

    # Save to subject-specific subfolder
    subj_dir = os.path.join(PREPROCESSED_PATH, subj_key)
    os.makedirs(subj_dir)

    subj_files = []
    for chunk_idx in range(clip_num):
        input_path = os.path.join(subj_dir, f"{subj_key}_input{chunk_idx}.npy")
        label_path = os.path.join(subj_dir, f"{subj_key}_label{chunk_idx}.npy")

        np.save(input_path, data_clips[chunk_idx])   # (CHUNK_LENGTH, H, W, 3)
        np.save(label_path, label_clips[chunk_idx])  # (CHUNK_LENGTH,)
        subj_files.append(input_path)

    all_input_files.extend(subj_files)
    print(f"  {clip_num} clips -> {subj_dir}\n")

print(f"Total clips saved: {len(all_input_files)}")
print("\nFolder structure:")
for subj in subjects:
    d = os.path.join(PREPROCESSED_PATH, subj["subj_key"])
    n = len(glob.glob(os.path.join(d, "*_input*.npy")))
    print(f"  {subj['subj_key']}/  ({n} clips)")
# Out:
# Cleared and recreated: /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE
#
# === Processing S000 ===
#   Video: 2706 frames @ 30 fps
#   PPG green: min=-286206, max=237092
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S000
#
# === Processing S001 ===
#   Video: 2691 frames @ 30 fps
#   PPG green: min=-23646, max=248396
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S001
#
# === Processing S002 ===
#   Video: 2789 frames @ 30 fps
#   PPG green: min=-44811, max=180257
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S002
#
# === Processing S003 ===
#   Video: 2729 frames @ 30 fps
#   PPG green: min=-104560, max=349890
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S003
#
# === Processing S004 ===
#   Video: 2722 frames @ 30 fps
#   PPG green: min=-300061, max=200804
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S004
#
# === Processing S005 ===
#   Video: 2724 frames @ 30 fps
#   PPG green: min=-33448, max=492196
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S005
#
# === Processing S006 ===
#   Video: 2725 frames @ 30 fps
#   PPG green: min=-321476, max=264955
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S006
#
# === Processing S007 ===
#   Video: 2743 frames @ 30 fps
#   PPG green: min=-90427, max=213122
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S007
#
# === Processing S008 ===
#   Video: 2743 frames @ 30 fps
#   PPG green: min=-113616, max=167673
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S008
#
# === Processing S009 ===
#   Video: 2710 frames @ 30 fps
#   PPG green: min=-109992, max=279004
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S009
#
# === Processing S010 ===
#   Video: 2730 frames @ 30 fps
#   PPG green: min=-179613, max=246435
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S010
#
# === Processing S011 ===
#   Video: 2711 frames @ 30 fps
#   PPG green: min=-59972, max=201534
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S011
#
# === Processing S012 ===
#   Video: 2784 frames @ 30 fps
#   PPG green: min=-50970, max=373887
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S012
#
# === Processing S013 ===
#   Video: 2736 frames @ 30 fps
#   PPG green: min=-72632, max=203814
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S013
#
# === Processing S014 ===
#   Video: 2719 frames @ 30 fps
#   PPG green: min=-161204, max=212654
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S014
#
# === Processing S015 ===
#   Video: 2829 frames @ 30 fps
#   PPG green: min=-597019, max=350110
#   22 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S015
#
# === Processing S016 ===
#   Video: 2656 frames @ 30 fps
#   PPG green: min=-108990, max=304144
#   20 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S016
#
# === Processing S017 ===
#   Video: 2654 frames @ 30 fps
#   PPG green: min=-182178, max=77612
#   20 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S017
#
# === Processing S018 ===
#   Video: 2947 frames @ 30 fps
#   PPG green: min=-150662, max=158070
#   23 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S018
#
# === Processing S019 ===
#   Video: 2732 frames @ 30 fps
#   PPG green: min=-115443, max=194697
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S019
#
# === Processing S020 ===
#   Video: 2774 frames @ 30 fps
#   PPG green: min=-37654, max=316580
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S020
#
# === Processing S021 ===
#   Video: 2721 frames @ 30 fps
#   PPG green: min=-179649, max=402769
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S021
#
# === Processing S022 ===
#   Video: 2748 frames @ 30 fps
#   PPG green: min=-101214, max=210936
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S022
#
# === Processing S023 ===
#   Video: 2726 frames @ 30 fps
#   PPG green: min=-293717, max=59176
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S023
#
# === Processing S024 ===
#   Video: 2741 frames @ 30 fps
#   PPG green: min=-159887, max=372878
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S024
#
# === Processing S025 ===
#   Video: 2722 frames @ 30 fps
#   PPG green: min=-443773, max=263037
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S025
#
# === Processing S026 ===
#   Video: 2704 frames @ 30 fps
#   PPG green: min=-72124, max=104278
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S026
#
# === Processing S027 ===
#   Video: 2746 frames @ 30 fps
#   PPG green: min=-58744, max=85669
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S027
#
# === Processing S028 ===
#   Video: 2731 frames @ 30 fps
#   PPG green: min=-37237, max=308515
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S028
#
# === Processing S029 ===
#   Video: 2716 frames @ 30 fps
#   PPG green: min=-164652, max=307405
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S029
#
# === Processing S030 ===
#   Video: 2737 frames @ 30 fps
#   PPG green: min=-109443, max=247353
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S030
#
# === Processing S031 ===
#   Video: 2769 frames @ 30 fps
#   PPG green: min=-24421, max=188761
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S031
#
# === Processing S032 ===
#   Video: 2703 frames @ 30 fps
#   PPG green: min=-216669, max=192105
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S032
#
# === Processing S033 ===
#   Video: 2704 frames @ 30 fps
#   PPG green: min=-261324, max=207806
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S033
#
# === Processing S034 ===
#   Video: 2748 frames @ 30 fps
#   PPG green: min=-53557, max=248225
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S034
#
# === Processing S035 ===
#   Video: 2717 frames @ 30 fps
#   PPG green: min=-169635, max=219457
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S035
#
# === Processing S036 ===
#   Video: 2737 frames @ 30 fps
#   PPG green: min=-117184, max=173146
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S036
#
# === Processing S037 ===
#   Video: 2718 frames @ 30 fps
#   PPG green: min=-29667, max=231155
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S037
#
# === Processing S038 ===
#   Video: 2715 frames @ 30 fps
#   PPG green: min=-92207, max=188325
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S038
#
# === Processing S039 ===
#   Video: 2705 frames @ 30 fps
#   PPG green: min=-139753, max=285549
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S039
#
# === Processing S040 ===
#   Video: 2768 frames @ 30 fps
#   PPG green: min=-55143, max=259367
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S040
#
# === Processing S041 ===
#   Video: 2735 frames @ 30 fps
#   PPG green: min=-195965, max=254305
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S041
#
# === Processing S042 ===
#   Video: 2694 frames @ 30 fps
#   PPG green: min=-20947, max=141819
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S042
#
# === Processing S043 ===
#   Video: 2746 frames @ 30 fps
#   PPG green: min=-24592, max=308276
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S043
#
# === Processing S044 ===
#   Video: 2711 frames @ 30 fps
#   PPG green: min=-616667, max=322272
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S044
#
# === Processing S045 ===
#   Video: 2732 frames @ 30 fps
#   PPG green: min=-82055, max=59414
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S045
#
# === Processing S046 ===
#   Video: 2743 frames @ 30 fps
#   PPG green: min=-9431, max=147064
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S046
#
# === Processing S047 ===
#   Video: 2733 frames @ 30 fps
#   PPG green: min=-63522, max=134755
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S047
#
# === Processing S048 ===
#   Video: 2720 frames @ 30 fps
#   PPG green: min=-158215, max=300182
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S048
#
# === Processing S049 ===
#   Video: 2822 frames @ 30 fps
#   PPG green: min=-192500, max=344428
#   22 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S049
#
# === Processing S050 ===
#   Video: 2741 frames @ 30 fps
#   PPG green: min=-380334, max=266497
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S050
#
# === Processing S051 ===
#   Video: 2688 frames @ 30 fps
#   PPG green: min=-76380, max=331581
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S051
#
# === Processing S052 ===
#   Video: 2792 frames @ 30 fps
#   PPG green: min=-29433, max=161872
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S052
#
# === Processing S053 ===
#   Video: 2808 frames @ 30 fps
#   PPG green: min=-73778, max=403454
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S053
#
# === Processing S054 ===
#   Video: 2795 frames @ 30 fps
#   PPG green: min=-39000, max=216219
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S054
#
# === Processing S055 ===
#   Video: 2747 frames @ 30 fps
#   PPG green: min=-79170, max=216042
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S055
#
# === Processing S056 ===
#   Video: 2695 frames @ 30 fps
#   PPG green: min=-177766, max=235887
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S056
#
# === Processing S057 ===
#   Video: 2739 frames @ 30 fps
#   PPG green: min=-110664, max=309984
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S057
#
# === Processing S058 ===
#   Video: 2699 frames @ 30 fps
#   PPG green: min=-28316, max=316982
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S058
#
# === Processing S059 ===
#   Video: 2689 frames @ 30 fps
#   PPG green: min=-149679, max=240053
#   21 clips -> /home/naver/disk2/HoangDPB/rPPG-Toolbox/preprocessed_data/groupE/S059
#
# Total clips saved: 1262
#
# Folder structure:
#   S000/  (21 clips)
#   S001/  (21 clips)
#   S002/  (21 clips)
#   S003/  (21 clips)
#   S004/  (21 clips)
#   S005/  (21 clips)
#   S006/  (21 clips)
#   S007/  (21 clips)
#   S008/  (21 clips)
#   S009/  (21 clips)
#   S010/  (21 clips)
#   S011/  (21 clips)
#   S012/  (21 clips)
#   S013/  (21 clips)
#   S014/  (21 clips)
#   S015/  (22 clips)
#   S016/  (20 clips)
#   S017/  (20 clips)
#   S018/  (23 clips)
#   S019/  (21 clips)
#   S020/  (21 clips)
#   S021/  (21 clips)
#   S022/  (21 clips)
#   S023/  (21 clips)
#   S024/  (21 clips)
#   S025/  (21 clips)
#   S026/  (21 clips)
#   S027/  (21 clips)
#   S028/  (21 clips)
#   S029/  (21 clips)
#   S030/  (21 clips)
#   S031/  (21 clips)
#   S032/  (21 clips)
#   S033/  (21 clips)
#   S034/  (21 clips)
#   S035/  (21 clips)
#   S036/  (21 clips)
#   S037/  (21 clips)
#   S038/  (21 clips)
#   S039/  (21 clips)
#   S040/  (21 clips)
#   S041/  (21 clips)
#   S042/  (21 clips)
#   S043/  (21 clips)
#   S044/  (21 clips)
#   S045/  (21 clips)
#   S046/  (21 clips)
#   S047/  (21 clips)
#   S048/  (21 clips)
#   S049/  (22 clips)
#   S050/  (21 clips)
#   S051/  (21 clips)
#   S052/  (21 clips)
#   S053/  (21 clips)
#   S054/  (21 clips)
#   S055/  (21 clips)
#   S056/  (21 clips)
#   S057/  (21 clips)
#   S058/  (21 clips)
#   S059/  (21 clips)

# %%
# PyTorch Dataset + DataLoader

class PhysMambaDataset(Dataset):

    def __init__(self, input_files):
        self.inputs = sorted(input_files)
        self.labels = [
            f.replace("input", "label")
            for f in self.inputs
        ]

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, index):
        data  = np.float32(np.load(self.inputs[index]))   # (D, H, W, 3)
        label = np.float32(np.load(self.labels[index]))   # (D,)

        # NDHWC -> NCDHW: transpose to (3, D, H, W)
        data = np.transpose(data, (3, 0, 1, 2))

        fname      = os.path.basename(self.inputs[index])
        split_idx  = fname.index("_")
        subject_id = fname[:split_idx]
        chunk_id   = fname[split_idx + 6:].split(".")[0]  # +6 skips "_input"

        return data, label, subject_id, chunk_id


dataset = PhysMambaDataset(all_input_files)
loader  = DataLoader(dataset, batch_size=4, shuffle=False, num_workers=4)
print(f"Dataset: {len(dataset)} clips")
print(f"DataLoader ready: {len(loader)} batches")
# Out:
# Dataset: 1262 clips
# DataLoader ready: 316 batches

# %%
# Post-processing helpers

def detrend(signal_in, lambda_val=100):
    """Smoothness-priors detrending (Tarvainen et al.)."""
    T_len = len(signal_in)
    H_mat = np.eye(T_len)
    ones  = np.ones(T_len)
    D_mat = (np.diag(ones[:-2], -2)
             - 2 * np.diag(ones[:-1], -1)
             + np.diag(ones))
    D_mat = D_mat[2:, :]
    inv   = np.linalg.inv(H_mat + lambda_val ** 2 * D_mat.T @ D_mat)
    return (H_mat - inv) @ signal_in


def bandpass_filter(sig, fs, low, high, order=1):
    """Zero-phase Butterworth bandpass filter."""
    b, a = signal.butter(order, [low / fs * 2, high / fs * 2], btype="bandpass")
    return signal.filtfilt(b, a, sig.astype(np.float64))


def fft_peak_hz(sig, fs, low, high):
    """Return dominant frequency (Hz) in [low, high] Hz via FFT."""
    N = 1
    while N < len(sig):
        N *= 2
    freqs, pxx = periodogram(sig, fs=fs, nfft=N, detrend=False)
    mask = (freqs >= low) & (freqs <= high)
    if not mask.any():
        return 0.0
    return float(freqs[mask][np.argmax(pxx[mask])])


def calculate_snr(pred_ppg, hr_label_bpm, fs, low_pass=0.6, high_pass=3.3):
    """Signal-to-noise ratio at HR harmonics vs background noise (dB)."""
    N = 1
    while N < len(pred_ppg):
        N *= 2
    freqs, pxx = periodogram(pred_ppg, fs=fs, nfft=N, detrend=False)

    f1  = hr_label_bpm / 60.0
    f2  = 2 * f1
    dev = 6.0 / 60.0  # +-6 bpm tolerance

    sig_mask   = (((freqs >= f1 - dev) & (freqs <= f1 + dev))
                  | ((freqs >= f2 - dev) & (freqs <= f2 + dev)))
    noise_mask = ((freqs >= low_pass) & (freqs <= high_pass) & ~sig_mask)

    sig_power   = pxx[sig_mask].sum()
    noise_power = pxx[noise_mask].sum()
    if noise_power == 0:
        return float("inf")
    return float(10.0 * np.log10(sig_power / noise_power))


def _reform_from_dict(chunk_dict):
    """Concatenate chunks in sorted key order into a 1-D array."""
    return np.concatenate([chunk_dict[k] for k in sorted(chunk_dict.keys())])


def process_bvp(pred_chunks, label_chunks, fs=30, diff_flag=True):
    """Per-subject BVP post-processing.

    diff_flag=True: DiffNormalized labels -> cumsum before detrend.
    """
    pred  = _reform_from_dict(pred_chunks).astype(np.float64)
    label = _reform_from_dict(label_chunks).astype(np.float64)

    if diff_flag:
        pred  = detrend(np.cumsum(pred),  100)
        label = detrend(np.cumsum(label), 100)
    else:
        pred  = detrend(pred,  100)
        label = detrend(label, 100)

    pred_processed  = bandpass_filter(pred,  fs, low=0.6, high=3.3)
    label_processed = bandpass_filter(label, fs, low=0.6, high=3.3)

    hr_pred  = fft_peak_hz(pred_processed,  fs, 0.6, 3.3) * 60.0
    hr_label = fft_peak_hz(label_processed, fs, 0.6, 3.3) * 60.0
    snr_db   = calculate_snr(pred_processed, hr_label, fs)

    return hr_pred, hr_label, snr_db, pred_processed

# %%
# Blink rate detection

def detect_blink_rate(video_path, fps=30, large_box_coef=1.5):
    """Estimate blink rate (blinks/min) using eye-strip brightness analysis.

    Steps:
      1. Detect face on frame 0 with Haar Cascade.
      2. Define eye strip = rows [20%, 50%] of face bbox height.
      3. Compute mean grayscale brightness in eye strip per frame.
      4. Invert (blinks = dips) and bandpass filter [0.1, 0.9] Hz.
      5. Count peaks with minimum separation of 1 second.
    """
    frames = read_video_frames(video_path)
    T = len(frames)

    xml_path = cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
    detector = cv2.CascadeClassifier(xml_path)
    gray0 = cv2.cvtColor(frames[0], cv2.COLOR_RGB2GRAY)
    faces = detector.detectMultiScale(gray0, scaleFactor=1.3, minNeighbors=5)
    H, W = frames[0].shape[:2]

    if len(faces) > 0:
        x, y, fw, fh = max(faces, key=lambda f: f[2])
        x  = max(0, int(x  - (large_box_coef - 1.0) / 2.0 * fw))
        y  = max(0, int(y  - (large_box_coef - 1.0) / 2.0 * fh))
        fw = min(int(fw * large_box_coef), W - x)
        fh = min(int(fh * large_box_coef), H - y)
    else:
        x, y, fw, fh = 0, 0, W, H

    eye_top    = y + int(fh * 0.20)
    eye_bottom = y + int(fh * 0.50)
    eye_left   = x
    eye_right  = x + fw

    brightness = np.array([
        np.mean(cv2.cvtColor(f, cv2.COLOR_RGB2GRAY)[eye_top:eye_bottom, eye_left:eye_right])
        for f in frames
    ])

    # blinks = dips in brightness -> invert for find_peaks
    brightness_inv = -brightness.astype(np.float64)

    # bandpass [0.1, 0.9] Hz = [6, 54] blinks/min
    b, a = signal.butter(2, [0.1 / fps * 2, 0.9 / fps * 2], btype="bandpass")
    filtered = signal.filtfilt(b, a, brightness_inv)

    # minimum 1 second between detected blinks
    min_dist = int(fps)
    peaks, _ = signal.find_peaks(filtered, distance=min_dist)

    duration_min = T / fps / 60.0
    return len(peaks) / duration_min


# Compute blink rate for each subject
blink_rate_dict = {}
for subj in subjects:
    subj_key   = subj["subj_key"]
    video_path = subj["video_path"]
    print(f"  {subj_key} ...", end=" ", flush=True)
    blink_rate = detect_blink_rate(video_path, fps=VIDEO_FPS)
    blink_rate_dict[subj_key] = blink_rate
    print(f"{blink_rate:.2f} blinks/min")

print("\nBlink rates:", {k: f"{v:.2f}" for k, v in blink_rate_dict.items()})
# Out:
#   S000 ... 27.94 blinks/min
#   S001 ... 25.42 blinks/min
#   S002 ... 30.98 blinks/min
#   S003 ... 28.36 blinks/min
#   S004 ... 29.10 blinks/min
#   S005 ... 28.41 blinks/min
#   S006 ... 24.44 blinks/min
#   S007 ... 28.22 blinks/min
#   S008 ... 26.90 blinks/min
#   S009 ... 32.55 blinks/min
#   S010 ... 27.69 blinks/min
#   S011 ... 29.88 blinks/min
#   S012 ... 27.80 blinks/min
#   S013 ... 28.95 blinks/min
#   S014 ... 31.78 blinks/min
#   S015 ... 25.45 blinks/min
#   S016 ... 31.85 blinks/min
#   S017 ... 27.81 blinks/min
#   S018 ... 26.26 blinks/min
#   S019 ... 28.33 blinks/min
#   S020 ... 25.31 blinks/min
#   S021 ... 26.46 blinks/min
#   S022 ... 31.44 blinks/min
#   S023 ... 27.73 blinks/min
#   S024 ... 24.95 blinks/min
#   S025 ... 27.11 blinks/min
#   S026 ... 31.95 blinks/min
#   S027 ... 29.50 blinks/min
#   S028 ... 27.68 blinks/min
#   S029 ... 29.82 blinks/min
#   S030 ... 28.94 blinks/min
#   S031 ... 30.55 blinks/min
#   S032 ... 27.30 blinks/min
#   S033 ... 25.30 blinks/min
#   S034 ... 28.17 blinks/min
#   S035 ... 29.15 blinks/min
#   S036 ... 26.96 blinks/min
#   S037 ... 30.46 blinks/min
#   S038 ... 27.85 blinks/min
#   S039 ... 25.95 blinks/min
#   S040 ... 30.56 blinks/min
#   S041 ... 24.35 blinks/min
#   S042 ... 31.40 blinks/min
#   S043 ... 28.19 blinks/min
#   S044 ... 27.22 blinks/min
#   S045 ... 30.97 blinks/min
#   S046 ... 24.94 blinks/min
#   S047 ... 23.05 blinks/min
#   S048 ... 28.46 blinks/min
#   S049 ... 22.32 blinks/min
#   S050 ... 27.58 blinks/min
#   S051 ... 25.45 blinks/min
#   S052 ... 20.63 blinks/min
#   S053 ... 28.85 blinks/min
#   S054 ... 27.69 blinks/min
#   S055 ... 24.24 blinks/min
#   S056 ... 30.06 blinks/min
#   S057 ... 30.89 blinks/min
#   S058 ... 28.01 blinks/min
#   S059 ... 20.08 blinks/min
#
# Blink rates: {'S000': '27.94', 'S001': '25.42', 'S002': '30.98', 'S003': '28.36', 'S004': '29.10', 'S005': '28.41', 'S006': '24.44', 'S007': '28.22', 'S008': '26.90', 'S009': '32.55', 'S010': '27.69', 'S011': '29.88', 'S012': '27.80', 'S013': '28.95', 'S014': '31.78', 'S015': '25.45', 'S016': '31.85', 'S017': '27.81', 'S018': '26.26', 'S019': '28.33', 'S020': '25.31', 'S021': '26.46', 'S022': '31.44', 'S023': '27.73', 'S024': '24.95', 'S025': '27.11', 'S026': '31.95', 'S027': '29.50', 'S028': '27.68', 'S029': '29.82', 'S030': '28.94', 'S031': '30.55', 'S032': '27.30', 'S033': '25.30', 'S034': '28.17', 'S035': '29.15', 'S036': '26.96', 'S037': '30.46', 'S038': '27.85', 'S039': '25.95', 'S040': '30.56', 'S041': '24.35', 'S042': '31.40', 'S043': '28.19', 'S044': '27.22', 'S045': '30.97', 'S046': '24.94', 'S047': '23.05', 'S048': '28.46', 'S049': '22.32', 'S050': '27.58', 'S051': '25.45', 'S052': '20.63', 'S053': '28.85', 'S054': '27.69', 'S055': '24.24', 'S056': '30.06', 'S057': '30.89', 'S058': '28.01', 'S059': '20.08'}

# %%
# Inference loop -> per-subject results -> aggregate metrics -> export
# Results saved to results_groupE/{model_name}/

# lookup: subj_key -> subject info dict
subjects_by_key = {s["subj_key"]: s for s in subjects}

# blink_rate_dict is populated by the blink detection cell
if "blink_rate_dict" not in dir():
    blink_rate_dict = {}

FS = VIDEO_FPS

for MODEL_LABEL, MODEL_NAME, MODEL_REL_PATH in MODELS:
    MODEL_PATH = os.path.join(REPO_ROOT, MODEL_REL_PATH)
    print(f"\n{'='*70}")
    print(f"Model: {MODEL_LABEL}")
    print(f"Path:  {MODEL_PATH}")
    print(f"{'='*70}")

    # Load pretrained PhysMamba model
    model = PhysMamba(frames=CHUNK_LENGTH)

    state_dict = torch.load(MODEL_PATH, map_location=DEVICE)

    # strip 'module.' prefix if present (DataParallel artifact)
    if any(k.startswith("module.") for k in state_dict.keys()):
        state_dict = {k[len("module."):]: v for k, v in state_dict.items()}

    model.load_state_dict(state_dict)
    model = model.to(DEVICE)
    model.eval()

    num_params = sum(p.numel() for p in model.parameters())
    print(f"Model loaded. Total parameters: {num_params:,}")

    # Run inference
    bvp_preds_dict  = {}  # subj_key -> {chunk_id: np.ndarray}
    bvp_labels_dict = {}

    with torch.no_grad():
        for batch in tqdm(loader, desc="Inference"):
            data, labels_batch, batch_subjects, batch_chunk_ids = batch

            # data shape: (N, 3, D, H, W) -- already NCDHW from dataset
            data = data.to(DEVICE)

            pred_ppg = model(data)  # (N, D)

            pred_ppg_np  = pred_ppg.cpu().numpy()
            labels_np    = labels_batch.numpy()

            N = pred_ppg_np.shape[0]
            for i in range(N):
                subj = batch_subjects[i]
                cid  = int(batch_chunk_ids[i])

                if subj not in bvp_preds_dict:
                    bvp_preds_dict[subj]  = {}
                    bvp_labels_dict[subj] = {}

                bvp_preds_dict[subj][cid]  = pred_ppg_np[i]   # (D,)
                bvp_labels_dict[subj][cid] = labels_np[i]     # (D,)

    print(f"\nInference complete. Subjects: {sorted(bvp_preds_dict.keys())}")

    # Compute per-subject results
    per_subject_results = []
    hr_preds_all = []
    gt_hrs_all   = []
    snr_all      = []

    print(f"\n{'Subject':<10} {'HR_pred':>10} {'HR_gt':>10} {'HR_err':>8} {'SNR':>7} {'Blinks':>7}")
    print("-" * 60)

    for subj_key in sorted(bvp_preds_dict.keys()):
        hr_pred, hr_label, _, pred_processed = process_bvp(
            bvp_preds_dict[subj_key], bvp_labels_dict[subj_key], fs=FS, diff_flag=True
        )

        gt_hr      = subjects_by_key[subj_key]["gt_hr"]
        snr_db     = calculate_snr(pred_processed, gt_hr, FS)
        blink_rate = blink_rate_dict.get(subj_key, float("nan"))
        hr_err     = hr_pred - gt_hr

        # map subj_key ("S000") back to original ID ("S_000")
        subj_id = subj_key[0] + "_" + subj_key[1:]

        per_subject_results.append({
            "name":                subj_id,
            "predicted_heartrate": hr_pred,
            "real_heartrate":      gt_hr,
            "heartrate_error":     hr_err,
            "blink_rate":          blink_rate,
            "snr_db":              snr_db,
        })

        hr_preds_all.append(hr_pred)
        gt_hrs_all.append(gt_hr)
        snr_all.append(snr_db)

        print(f"{subj_id:<10} {hr_pred:>10.3f} {gt_hr:>10.3f} {hr_err:>8.3f} {snr_db:>7.2f} {blink_rate:>7.2f}")

    hr_preds_all = np.array(hr_preds_all)
    gt_hrs_all   = np.array(gt_hrs_all)
    snr_all      = np.array(snr_all)

    # Aggregate metrics
    n = len(hr_preds_all)
    assert n > 0, "No subjects to evaluate."

    err   = hr_preds_all - gt_hrs_all
    abs_e = np.abs(err)
    sq_e  = err ** 2
    rel_e = abs_e / (np.abs(gt_hrs_all) + 1e-9)

    mae       = float(np.mean(abs_e))
    mae_se    = float(np.std(abs_e) / np.sqrt(n))

    rmse      = float(np.sqrt(np.mean(sq_e)))
    rmse_se   = float(np.sqrt(np.std(sq_e) / np.sqrt(n)))

    mape      = float(np.mean(rel_e) * 100.0)
    mape_se   = float(np.std(rel_e) / np.sqrt(n) * 100.0)

    if n >= 2:
        pearson_r  = float(np.corrcoef(hr_preds_all, gt_hrs_all)[0, 1])
        pearson_se = float(np.sqrt(max(0.0, (1 - pearson_r ** 2) / (n - 2))))
    else:
        pearson_r, pearson_se = float("nan"), float("nan")

    mean_snr    = float(np.mean(snr_all))
    mean_snr_se = float(np.std(snr_all) / np.sqrt(n))

    print(f"\nAggregate Metrics ({MODEL_LABEL}):")
    print(f"  MAE     : {mae:.4f} +/- {mae_se:.4f} bpm")
    print(f"  RMSE    : {rmse:.4f} +/- {rmse_se:.4f} bpm")
    print(f"  MAPE    : {mape:.4f} +/- {mape_se:.4f} %")
    print(f"  Pearson : {pearson_r:.4f} +/- {pearson_se:.4f}")
    print(f"  SNR     : {mean_snr:.4f} +/- {mean_snr_se:.4f} dB")

    # Export to per-model subdirectory
    model_output_dir = os.path.join(OUTPUT_DIR, MODEL_LABEL)
    os.makedirs(model_output_dir, exist_ok=True)

    metrics_dict = {
        "model":      MODEL_LABEL,
        "n_subjects": n,
        "evaluation_method": "FFT",
        "bvp_bandpass_hz":   [0.6, 3.3],
        "aggregate_metrics": {
            "MAE":     {"value": mae,      "se": mae_se,      "unit": "bpm"},
            "RMSE":    {"value": rmse,     "se": rmse_se,     "unit": "bpm"},
            "MAPE":    {"value": mape,     "se": mape_se,     "unit": "%"},
            "Pearson": {"value": pearson_r, "se": pearson_se, "unit": ""},
            "SNR":     {"value": mean_snr, "se": mean_snr_se, "unit": "dB"},
        },
        "per_subject": [
            {
                "name":               r["name"],
                "predicted_heartrate": r["predicted_heartrate"],
                "real_heartrate":      r["real_heartrate"],
                "heartrate_error":     r["heartrate_error"],
                "snr_db":              r["snr_db"],
            }
            for r in per_subject_results
        ],
    }

    json_path = os.path.join(model_output_dir, "metrics.json")
    with open(json_path, "w") as fh:
        json.dump(metrics_dict, fh, indent=2)
    print(f"\nMetrics saved to: {json_path}")

    csv_rows = []
    for r in per_subject_results:
        csv_rows.append({
            "name":               r["name"],
            "predicted_heartrate": r["predicted_heartrate"],
            "real_heartrate":      r["real_heartrate"],
            "heartrate_error":     r["heartrate_error"],
            "blink_rate":          r["blink_rate"],
        })

    results_df = pd.DataFrame(csv_rows, columns=[
        "name", "predicted_heartrate", "real_heartrate",
        "heartrate_error", "blink_rate"
    ])

    csv_path = os.path.join(model_output_dir, "ppg_results.csv")
    results_df.to_csv(csv_path, index=False)

    print(f"CSV saved to: {csv_path}")
    print()
    print(results_df.to_string(index=False))

    # Clean up model from GPU
    del model
    torch.cuda.empty_cache()

print(f"\n\nAll models processed. Results in: {OUTPUT_DIR}")
# Out:
# ======================================================================
# Model: PURE_PhysMamba
# Path:  /home/naver/disk2/HoangDPB/rPPG-Toolbox/final_model_release/PURE_PhysMamba_DiffNormalized.pth
# ======================================================================
# Model loaded. Total parameters: 728,769
# Inference: 100%|██████████| 316/316 [04:52<00:00,  1.08it/s]
# Inference complete. Subjects: ['S000', 'S001', 'S002', 'S003', 'S004', 'S005', 'S006', 'S007', 'S008', 'S009', 'S010', 'S011', 'S012', 'S013', 'S014', 'S015', 'S016', 'S017', 'S018', 'S019', 'S020', 'S021', 'S022', 'S023', 'S024', 'S025', 'S026', 'S027', 'S028', 'S029', 'S030', 'S031', 'S032', 'S033', 'S034', 'S035', 'S036', 'S037', 'S038', 'S039', 'S040', 'S041', 'S042', 'S043', 'S044', 'S045', 'S046', 'S047', 'S048', 'S049', 'S050', 'S051', 'S052', 'S053', 'S054', 'S055', 'S056', 'S057', 'S058', 'S059']
#
# Subject       HR_pred      HR_gt   HR_err     SNR  Blinks
# ------------------------------------------------------------
# S_000          87.012     83.537    3.474   -5.42   27.94
# S_001          79.102     80.397   -1.296   -0.11   25.42
# S_002          70.312    122.479  -52.167  -10.34   30.98
# S_003          72.070    114.922  -42.851   -9.08   28.36
# S_004          71.631     79.125   -7.494   -6.06   29.10
# S_005          87.891     92.787   -4.897   -7.83   28.41
# S_006         106.348    106.728   -0.381   -2.23   24.44
# S_007         101.514    103.531   -2.017   -5.76   28.22
# S_008          90.527     90.296    0.231   -3.93   26.90
# S_009          78.662     81.089   -2.426    0.63   32.55
# S_010          97.998     98.062   -0.064   -5.01   27.69
# S_011          79.102     72.568    6.534   -4.51   29.88
# S_012          74.707     81.488   -6.781   -5.55   27.80
# S_013         108.105     90.245   17.861   -7.01   28.95
# S_014         101.074     83.333   17.741   -6.97   31.78
# S_015          77.783     79.212   -1.429   -4.79   25.45
# S_016          97.559     95.481    2.078   -5.06   31.85
# S_017          58.887     90.586  -31.699   -8.16   27.81
# S_018          95.801     86.000    9.801   -6.04   26.26
# S_019          97.559     96.537    1.021   -5.60   28.33
# S_020          79.102     80.927   -1.825   -0.79   25.31
# S_021         119.092    118.465    0.627   -4.88   26.46
# S_022          65.039     87.143  -22.104   -7.92   31.44
# S_023          70.312     77.519   -7.206   -3.47   27.73
# S_024          76.025     77.182   -1.156   -1.87   24.95
# S_025          61.963     61.475    0.488   -2.34   27.11
# S_026          71.631     70.506    1.125   -0.78   31.95
# S_027          93.604    102.078   -8.474   -7.90   29.50
# S_028          70.752     73.887   -3.135   -3.87   27.68
# S_029          93.604     97.886   -4.283   -5.00   29.82
# S_030          82.178     79.427    2.751   -4.74   28.94
# S_031          57.568     91.395  -33.827   -8.52   30.55
# S_032          88.330     86.868    1.462   -0.44   27.30
# S_033          83.936     85.638   -1.702   -0.42   25.30
# S_034          93.604     94.286   -0.682   -5.78   28.17
# S_035          96.680    109.977  -13.298   -9.54   29.15
# S_036          83.057     81.469    1.588   -5.08   26.96
# S_037          72.510     71.817    0.693   -3.60   30.46
# S_038          65.918     66.025   -0.107   -2.37   27.85
# S_039          82.617    102.053  -19.436   -7.17   25.95
# S_040          93.604     90.463    3.140   -7.45   30.56
# S_041          79.102    117.712  -38.611   -9.73   24.35
# S_042          57.568     62.938   -5.370   -1.94   31.40
# S_043          64.600     57.781    6.819   -6.72   28.19
# S_044          73.389     75.181   -1.792    0.15   27.22
# S_045          77.783     75.650    2.133   -0.46   30.97
# S_046          64.160     62.875    1.285   -5.43   24.94
# S_047          77.344     70.927    6.417   -4.85   23.05
# S_048          86.572    101.671  -15.099   -7.25   28.46
# S_049          69.873     63.800    6.073   -4.23   22.32
# S_050          87.012     87.768   -0.757   -3.40   27.58
# S_051          79.102     80.165   -1.063   -3.10   25.45
# S_052          72.070     71.120    0.950   -4.17   20.63
# S_053          72.510     69.160    3.350   -1.25   28.85
# S_054          63.721     64.595   -0.875   -1.98   27.69
# S_055          71.191     73.000   -1.809    1.92   24.24
# S_056          95.801     97.210   -1.409   -4.09   30.06
# S_057          71.191     68.444    2.747   -2.66   30.89
# S_058          79.102     79.963   -0.861   -3.98   28.01
# S_059          61.084     78.739  -17.655   -8.50   20.08
#
# Aggregate Metrics (PURE_PhysMamba):
#   MAE     : 7.6070 +/- 1.4543 bpm
#   RMSE    : 13.5926 +/- 7.9061 bpm
#   MAPE    : 8.1935 +/- 1.3646 %
#   Pearson : 0.5990 +/- 0.1051
#   SNR     : -4.5737 +/- 0.3659 dB
#
# Metrics saved to: /home/naver/disk2/HoangDPB/rPPG-Toolbox/results/groupE/PPG_Dataset/PURE_PhysMamba/metrics.json
# CSV saved to: /home/naver/disk2/HoangDPB/rPPG-Toolbox/results/groupE/PPG_Dataset/PURE_PhysMamba/ppg_results.csv
#
#   name  predicted_heartrate  real_heartrate  heartrate_error  blink_rate
#  S_000            87.011719       83.537500         3.474219   27.937916
#  S_001            79.101562       80.397436        -1.295873   25.418060
#  S_002            70.312500      122.479167       -52.166667   30.978845
#  S_003            72.070312      114.921569       -42.851256   28.362037
#  S_004            71.630859       79.125000        -7.494141   29.096253
#  S_005            87.890625       92.787500        -4.896875   28.414097
#  S_006           106.347656      106.728395        -0.380739   24.440367
#  S_007           101.513672      103.530864        -2.017192   28.217280
#  S_008            90.527344       90.296296         0.231047   26.904849
#  S_009            78.662109       81.088608        -2.426498   32.546125
#  S_010            97.998047       98.061728        -0.063682   27.692308
#  S_011            79.101562       72.567901         6.533661   29.878274
#  S_012            74.707031       81.488095        -6.781064   27.801724
#  S_013           108.105469       90.244898        17.860571   28.947368
#  S_014           101.074219       83.333333        17.740885   31.776388
#  S_015            77.783203       79.211765        -1.428562   25.450689
#  S_016            97.558594       95.481013         2.077581   31.852410
#  S_017            58.886719       90.585714       -31.698996   27.807084
#  S_018            95.800781       86.000000         9.800781   26.263997
#  S_019            97.558594       96.537500         1.021094   28.330893
#  S_020            79.101562       80.926829        -1.825267   25.306417
#  S_021           119.091797      118.464789         0.627008   26.460860
#  S_022            65.039062       87.142857       -22.103795   31.441048
#  S_023            70.312500       77.518519        -7.206019   27.732942
#  S_024            76.025391       77.181818        -1.156428   24.954396
#  S_025            61.962891       61.475000         0.487891   27.112417
#  S_026            71.630859       70.506173         1.124687   31.952663
#  S_027            93.603516      102.077778        -8.474262   29.497451
#  S_028            70.751953       73.887324        -3.135371   27.682168
#  S_029            93.603516       97.886076        -4.282560   29.823270
#  S_030            82.177734       79.426829         2.750905   28.936792
#  S_031            57.568359       91.395062       -33.826702   30.552546
#  S_032            88.330078       86.868421         1.461657   27.302997
#  S_033            83.935547       85.637500        -1.701953   25.295858
#  S_034            93.603516       94.285714        -0.682199   28.165939
#  S_035            96.679688      109.977273       -13.297585   29.149798
#  S_036            83.056641       81.469136         1.587505   26.963829
#  S_037            72.509766       71.817073         0.692692   30.463576
#  S_038            65.917969       66.025000        -0.107031   27.845304
#  S_039            82.617188      102.053333       -19.436146   25.951941
#  S_040            93.603516       90.463415         3.140101   30.563584
#  S_041            79.101562      117.712329       -38.610766   24.351005
#  S_042            57.568359       62.938272        -5.369912   31.403118
#  S_043            64.599609       57.780822         6.818787   28.186453
#  S_044            73.388672       75.180723        -1.792051   27.222427
#  S_045            77.783203       75.650000         2.133203   30.966325
#  S_046            64.160156       62.875000         1.285156   24.936201
#  S_047            77.343750       70.926829         6.416921   23.051592
#  S_048            86.572266      101.670886       -15.098620   28.455882
#  S_049            69.873047       63.800000         6.073047   22.324592
#  S_050            87.011719       87.768293        -0.756574   27.581175
#  S_051            79.101562       80.164557        -1.062994   25.446429
#  S_052            72.070312       71.120482         0.949831   20.630372
#  S_053            72.509766       69.160000         3.349766   28.846154
#  S_054            63.720703       64.595238        -0.874535   27.692308
#  S_055            71.191406       73.000000        -1.808594   24.244631
#  S_056            95.800781       97.209877        -1.409095   30.055659
#  S_057            71.191406       68.444444         2.746962   30.887185
#  S_058            79.101562       79.962500        -0.860938   28.010374
#  S_059            61.083984       78.739130       -17.655146   20.081815
#
# ======================================================================
# Model: UBFC-rPPG_PhysMamba
# Path:  /home/naver/disk2/HoangDPB/rPPG-Toolbox/final_model_release/UBFC-rPPG_PhysMamba_DiffNormalized.pth
# ======================================================================
# Model loaded. Total parameters: 728,769
# Inference: 100%|██████████| 316/316 [05:26<00:00,  1.03s/it]
# Inference complete. Subjects: ['S000', 'S001', 'S002', 'S003', 'S004', 'S005', 'S006', 'S007', 'S008', 'S009', 'S010', 'S011', 'S012', 'S013', 'S014', 'S015', 'S016', 'S017', 'S018', 'S019', 'S020', 'S021', 'S022', 'S023', 'S024', 'S025', 'S026', 'S027', 'S028', 'S029', 'S030', 'S031', 'S032', 'S033', 'S034', 'S035', 'S036', 'S037', 'S038', 'S039', 'S040', 'S041', 'S042', 'S043', 'S044', 'S045', 'S046', 'S047', 'S048', 'S049', 'S050', 'S051', 'S052', 'S053', 'S054', 'S055', 'S056', 'S057', 'S058', 'S059']
#
# Subject       HR_pred      HR_gt   HR_err     SNR  Blinks
# ------------------------------------------------------------
# S_000          85.254     83.537    1.716   -4.21   27.94
# S_001          79.102     80.397   -1.296   -0.08   25.42
# S_002          70.312    122.479  -52.167  -10.19   30.98
# S_003          98.438    114.922  -16.484   -6.18   28.36
# S_004          75.586     79.125   -3.539   -3.05   29.10
# S_005          84.375     92.787   -8.412   -7.83   28.41
# S_006         106.348    106.728   -0.381   -0.28   24.44
# S_007         101.514    103.531   -2.017   -4.76   28.22
# S_008          89.209     90.296   -1.087   -3.73   26.90
# S_009          78.662     81.089   -2.426    0.98   32.55
# S_010          98.438     98.062    0.376   -4.18   27.69
# S_011          71.191     72.568   -1.376   -2.94   29.88
# S_012          79.980     81.488   -1.508   -2.97   27.80
# S_013         108.105     90.245   17.861   -6.73   28.95
# S_014          77.783     83.333   -5.550   -4.69   31.78
# S_015          77.783     79.212   -1.429   -1.76   25.45
# S_016          99.756     95.481    4.275   -3.36   31.85
# S_017         112.939     90.586   22.354   -8.39   27.81
# S_018          84.375     86.000   -1.625   -7.13   26.26
# S_019          84.375     96.537  -12.162   -5.97   28.33
# S_020          82.617     80.927    1.690    0.74   25.31
# S_021         118.213    118.465   -0.252   -5.44   26.46
# S_022          94.043     87.143    6.900   -6.36   31.44
# S_023          70.312     77.519   -7.206   -4.39   27.73
# S_024          76.025     77.182   -1.156   -2.82   24.95
# S_025          57.568     61.475   -3.907   -3.24   27.11
# S_026          71.631     70.506    1.125   -1.43   31.95
# S_027          93.604    102.078   -8.474   -5.82   29.50
# S_028          70.752     73.887   -3.135   -3.40   27.68
# S_029          94.482     97.886   -3.404   -2.07   29.82
# S_030          80.859     79.427    1.433   -4.12   28.94
# S_031          84.375     91.395   -7.020   -6.39   30.55
# S_032          86.133     86.868   -0.736   -1.45   27.30
# S_033          88.330     85.638    2.693    0.82   25.30
# S_034          93.604     94.286   -0.682   -3.64   28.17
# S_035         110.303    109.977    0.325   -5.54   29.15
# S_036          97.998     81.469   16.529   -3.49   26.96
# S_037          72.510     71.817    0.693   -2.08   30.46
# S_038          65.918     66.025   -0.107   -2.95   27.85
# S_039          86.133    102.053  -15.921   -7.25   25.95
# S_040          90.088     90.463   -0.376   -3.27   30.56
# S_041          70.312    117.712  -47.400   -8.82   24.35
# S_042          63.281     62.938    0.343   -3.12   31.40
# S_043          64.600     57.781    6.819   -6.84   28.19
# S_044          73.389     75.181   -1.792    0.05   27.22
# S_045          77.783     75.650    2.133   -0.82   30.97
# S_046          70.312     62.875    7.438   -5.42   24.94
# S_047          74.268     70.927    3.341   -4.96   23.05
# S_048         100.635    101.671   -1.036   -5.74   28.46
# S_049          64.160     63.800    0.360   -2.61   22.32
# S_050          87.012     87.768   -0.757   -1.13   27.58
# S_051          79.102     80.165   -1.063   -2.44   25.45
# S_052          72.949     71.120    1.829   -2.10   20.63
# S_053          72.510     69.160    3.350   -1.62   28.85
# S_054          64.600     64.595    0.004   -2.10   27.69
# S_055          71.191     73.000   -1.809    1.41   24.24
# S_056          95.801     97.210   -1.409   -1.50   30.06
# S_057          68.994     68.444    0.550   -1.33   30.89
# S_058          79.102     79.963   -0.861   -3.24   28.01
# S_059          61.084     78.739  -17.655   -8.48   20.08
#
# Aggregate Metrics (UBFC-rPPG_PhysMamba):
#   MAE     : 5.6959 +/- 1.2554 bpm
#   RMSE    : 11.2699 +/- 7.6289 bpm
#   MAPE    : 6.1227 +/- 1.1356 %
#   Pearson : 0.7110 +/- 0.0923
#   SNR     : -3.6975 +/- 0.3375 dB
#
# Metrics saved to: /home/naver/disk2/HoangDPB/rPPG-Toolbox/results/groupE/PPG_Dataset/UBFC-rPPG_PhysMamba/metrics.json
# CSV saved to: /home/naver/disk2/HoangDPB/rPPG-Toolbox/results/groupE/PPG_Dataset/UBFC-rPPG_PhysMamba/ppg_results.csv
#
#   name  predicted_heartrate  real_heartrate  heartrate_error  blink_rate
#  S_000            85.253906       83.537500         1.716406   27.937916
#  S_001            79.101562       80.397436        -1.295873   25.418060
#  S_002            70.312500      122.479167       -52.166667   30.978845
#  S_003            98.437500      114.921569       -16.484069   28.362037
#  S_004            75.585938       79.125000        -3.539062   29.096253
#  S_005            84.375000       92.787500        -8.412500   28.414097
#  S_006           106.347656      106.728395        -0.380739   24.440367
#  S_007           101.513672      103.530864        -2.017192   28.217280
#  S_008            89.208984       90.296296        -1.087312   26.904849
#  S_009            78.662109       81.088608        -2.426498   32.546125
#  S_010            98.437500       98.061728         0.375772   27.692308
#  S_011            71.191406       72.567901        -1.376495   29.878274
#  S_012            79.980469       81.488095        -1.507626   27.801724
#  S_013           108.105469       90.244898        17.860571   28.947368
#  S_014            77.783203       83.333333        -5.550130   31.776388
#  S_015            77.783203       79.211765        -1.428562   25.450689
#  S_016            99.755859       95.481013         4.274847   31.852410
#  S_017           112.939453       90.585714        22.353739   27.807084
#  S_018            84.375000       86.000000        -1.625000   26.263997
#  S_019            84.375000       96.537500       -12.162500   28.330893
#  S_020            82.617188       80.926829         1.690358   25.306417
#  S_021           118.212891      118.464789        -0.251898   26.460860
#  S_022            94.042969       87.142857         6.900112   31.441048
#  S_023            70.312500       77.518519        -7.206019   27.732942
#  S_024            76.025391       77.181818        -1.156428   24.954396
#  S_025            57.568359       61.475000        -3.906641   27.112417
#  S_026            71.630859       70.506173         1.124687   31.952663
#  S_027            93.603516      102.077778        -8.474262   29.497451
#  S_028            70.751953       73.887324        -3.135371   27.682168
#  S_029            94.482422       97.886076        -3.403654   29.823270
#  S_030            80.859375       79.426829         1.432546   28.936792
#  S_031            84.375000       91.395062        -7.020062   30.552546
#  S_032            86.132812       86.868421        -0.735609   27.302997
#  S_033            88.330078       85.637500         2.692578   25.295858
#  S_034            93.603516       94.285714        -0.682199   28.165939
#  S_035           110.302734      109.977273         0.325462   29.149798
#  S_036            97.998047       81.469136        16.528911   26.963829
#  S_037            72.509766       71.817073         0.692692   30.463576
#  S_038            65.917969       66.025000        -0.107031   27.845304
#  S_039            86.132812      102.053333       -15.920521   25.951941
#  S_040            90.087891       90.463415        -0.375524   30.563584
#  S_041            70.312500      117.712329       -47.399829   24.351005
#  S_042            63.281250       62.938272         0.342978   31.403118
#  S_043            64.599609       57.780822         6.818787   28.186453
#  S_044            73.388672       75.180723        -1.792051   27.222427
#  S_045            77.783203       75.650000         2.133203   30.966325
#  S_046            70.312500       62.875000         7.437500   24.936201
#  S_047            74.267578       70.926829         3.340749   23.051592
#  S_048           100.634766      101.670886        -1.036120   28.455882
#  S_049            64.160156       63.800000         0.360156   22.324592
#  S_050            87.011719       87.768293        -0.756574   27.581175
#  S_051            79.101562       80.164557        -1.062994   25.446429
#  S_052            72.949219       71.120482         1.828737   20.630372
#  S_053            72.509766       69.160000         3.349766   28.846154
#  S_054            64.599609       64.595238         0.004371   27.692308
#  S_055            71.191406       73.000000        -1.808594   24.244631
#  S_056            95.800781       97.209877        -1.409095   30.055659
#  S_057            68.994141       68.444444         0.549696   30.887185
#  S_058            79.101562       79.962500        -0.860938   28.010374
#  S_059            61.083984       78.739130       -17.655146   20.081815
#
#
# All models processed. Results in: /home/naver/disk2/HoangDPB/rPPG-Toolbox/results/groupE/PPG_Dataset
